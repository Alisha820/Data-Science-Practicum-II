# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from bs4 import BeautifulSoup

data = pd.read_csv ('/Users/alisha/Downloads/movies_dataset.csv')

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.boxofficemojo.com/year/world"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find_all('table')[0]
rows = table.find_all('tr')[1:]

for row in rows:
    columns = row.find_all('td')
    title = columns[1].text.strip()
    box_office_gross = columns[3].text.strip()
    print(title, box_office_gross)
# Out:
# The Super Mario Bros. Movie $353,170,890
# Ant-Man and the Wasp: Quantumania $212,913,580
# John Wick: Chapter 4 $160,235,180
# Creed III $155,241,208
# Scream VI $106,818,626
# Dungeons & Dragons: Honor Among Thieves $74,248,871
# Shazam! Fury of the Gods $57,474,575
# Pathaan $17,487,476
# Chebi: My Fluffy Friend -
# Cocaine Bear $64,378,330
# Titanic 25 Year Anniversary $15,033,795
# Magic Mike's Last Dance $26,005,156
# Demon Slayer: Kimetsu No Yaiba - To the Swordsmith Village $10,117,806
# 65 $31,872,012
# Knock at the Cabin $35,397,980
# Air $33,409,758
# Plane $32,111,181
# Jesus Revolution $51,988,184
# Mummies $4,275,970
# Missing $32,502,025
# Asterix & Obelix: The Middle Kingdom -
# 80 for Brady $39,330,588
# Operation Fortune: Ruse de guerre $6,496,125
# The Pope's Exorcist $9,006,368
# Alibi.com 2 -
# BTS: Yet to Come in Cinemas $8,093,270
# Doraemon the Movie: Nobita's Sky Utopia -
# The House of No Man -
# Champions $16,080,485
# Ride On $64,759
# The Legend & Butterfly -
# My Happy Marriage -
# A Guilty Conscience -
# The Point Men -
# Shin Kamen Rider -
# His Only Son $12,084,084
# Die Drei ??? - Erbe des Drachen -
# Epic Tails -
# What's Love Got to Do with It? -
# Renfield $8,026,475
# Sun and Concrete -
# House Party $9,002,247
# Rafadan Tayfa Galaktik Tayfa -
# Father & Soldier -
# The Wandering Earth II $5,023,132
# The Crime Is Mine -
# Pravednik -
# Manta, Manta - Zwoter Teil -
# Eiga 'Ichikei no karasu' -
# The Three Musketeers: D'Artagnan -
# Les petites victoires -
# Poyekhavshaya -
# And Yet, You Are So Sweet -
# Marlowe $4,350,243
# The Devil's Deal -
# Blue Giant -
# Infelices para Siempre -
# The Chosen Season 3 Finale $5,525,069
# Infinity Pool $5,078,400
# Phantom -
# Chi Chi Em Em 2 -
# Shylock's Children -
# Siêu lua gap siêu lay -
# Me contro Te - il Film: Missione Giungla -
# Emergency Landing -
# Someday or One Day -
# Sur les chemins noirs -
# Mavka: The Forest Song -
# Winnie the Pooh: Blood and Honey $1,750,639
# Detective Conan: Episode of Ai Haibara ~ Black Iron Mystery Train -
# IM HERO THE FINAL -
# Sage homme -
# Nyurnberg -
# Allelujah -
# Tu Jhoothi Main Makkaar $2,503,604
# Mari(dos) -
# The Book of Wonders -
# Kutsal Damacana 4 -
# ¡Que viva México! $161,222
# Besprintsipnyye v derevne -
# Un homme heureux -
# Maybe I Do $1,293,722
# O chem govoryat muzhchiny. Prostyye udovolstviya -
# La Syndicaliste -
# Les choses simples -
# Left Behind: Rise of the Antichrist $3,649,422
# The Journey: A Music Special from Andrea Bocelli $3,574,915
# SSSS.Gridman -
# Neposlushnaya -
# The Communion Girl -
# A Thousand and One $3,315,155
# Last Night of Amore -
# Tramite amicizia -
# All Your Faces -
# Switch -
# Nemesis the Movie: Mystery of Golden Spiral -
# Cats in the Museum -
# 2023 Oscar Nominated Short Films: Live Action $3,025,631
# Touken Ranbu 2 -
# Count -
# Two Tickets to Greece -
# Grazie ragazzi -
# Yudo: The Way of the Bath -
# Varisu -
# The Lulus -
# When Will It Be Again Like It Never Was Before -
# Come Out in Jesus Name $2,500,574
# Ostrov -
# Klem -
# Soulmate -
# Illegal Hayatlar -
# A Good Person $2,196,991
# The First Day of My Life -
# Billie Eilish Live at the O2 $1,290,000
# Rebound -
# Moving On $2,107,608
# Vaincre ou mourir -
# Heaven in Hell -
# Romina, VTM -
# Everything Under Control -
# Fear $2,090,261
# Svobodnyye otnosheniya -
# Woong-Nam -
# Skinamarink $2,052,272
# Mafia Mamma $2,032,202
# El hotel de los líos. García y García 2 -
# Caveman -
# Andre Rieu In Dublin 2023 -
# Do Unto Others -
# Divertimento -
# All Inclusive -
# Huesera: The Bone Woman -
# All of Those Voices -
# Blueback -
# Beautiful Disaster -
# Romancham -
# Byt -
# Thunivu -
# Princes of the Desert -
# Dads Versus Moms -
# Prání k narozeninám -
# Haita de actiune -
# Invalid -
# My Heart Puppy -
# Consecration $538,551
# Theory of Ambitions -
# Marui Video -
# Le clan -
# Nefarious $1,316,266
# Broken -
# Hidden Blade $803,189
# Baian the Assassin, M.D. Part 1 -
# Richard the Stork and the Mystery of the Great Jewel -
# Beshenstvo -
# Rye Lane -
# Tchaikovsky's Wife -
# No Dogs or Italians Allowed -
# The Lord of the Rings: The Return of the King 20th Anniversary $1,176,085
# Everything Everywhere All at Once 2023 Re-release -
# Filip -
# Nabil El Gamil Dr. Tagmeel -
# Grand Expectations -
# Dangerous Men -
# Masz ci los! -
# Bud chlap! -
# My Beautiful Man ～Eternal～ -
# Ramon -
# Mixed by Erry -
# Youssef Salem a du succès -
# Irati -
# Na Twoim miejscu -
# The Devil Conspiracy $765,218
# Umami -
# Tina & Bettina 2: The Comeback -
# Oh My Goodness! -
# Next Sohee -
# Elvis 2023  Re-release -
# Kutoppen - På sporet -
# Inside $897,190
# Un petit miracle -
# Duda & Dada The Secret of HooHoo Island -
# Waltair Veerayya $320,000
# Nada Que Ver -
# Wild Game -
# Tsarevny i Tainstvennaya gostya -
# Carrie and Superkola -
# National Theatre Live: The Crucible -
# Paint $780,021
# Let the River Flow -
# Malikappuram -
# Fireworks -
# Taximetristi -
# Munch -
# Eskortnitsa -
# Selfiee $335,775
# Opiekun -
# Gold Kingdom and Water Kingdom -
# The Mountain -
# Les gardiennes de la planète -
# Sugar and Stars -

# %%
# Load the movie dataset into a pandas DataFrame
movies_df = pd.read_csv("/Users/alisha/Downloads/movies_dataset.csv")

# Create an empty list to store the box office data
box_office_data = []

# Scrape the box office data and add it to the list
url = "https://www.boxofficemojo.com/year/world"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
table = soup.find_all('table')[0]
rows = table.find_all('tr')[1:]

for row in rows:
    columns = row.find_all('td')
    title = columns[1].text.strip()
    box_office_gross = columns[3].text.strip()
    box_office_data.append({"title": title, "box_office_gross": box_office_gross})

# Create a new DataFrame with the box office data
box_office_df = pd.DataFrame(box_office_data)

# Merge the box office DataFrame with the movie DataFrame based on the movie title and release date
merged_df = pd.merge(movies_df, box_office_df, on=["title"])

# Save the merged DataFrame to a new CSV file
merged_df.to_csv("merged_dataset.csv", index=False)
# Print the merged DataFrame
print(merged_df)
# Out:
#      Unnamed: 0  IMDb-rating appropriate_for              director downloads  \
# 0            13          6.6           PG-13           Peyton Reed    14,867
# 1            21          5.2           PG-13        Michael Jacobs       271
# 2            29          6.1               R           Neil Jordan       283
# 3            36          6.1               R           Neil Jordan       283
# 4            80          6.1               R           Neil Jordan       283
# ..          ...          ...             ...                   ...       ...
# 225        6677          5.4             NaN         Rick Alverson       189
# 226        8590          5.8       Not Rated       Mukul Abhyankar    42,893
# 227        9209          4.7             NaN                   NaN     2,287
# 228       12768          5.1           PG-13  Christian Cantamessa     3,645
# 229       15714          5.9               R         Todd Robinson    13,166
#
#          id             industry               language   posted_date  \
# 0    371992  Hollywood / English          English,Hindi  17 Feb, 2023
# 1    371115  Hollywood / English                English  30 Jan, 2023
# 2    371876  Hollywood / English                English  15 Feb, 2023
# 3    371876  Hollywood / English                English  15 Feb, 2023
# 4    371876  Hollywood / English                English  15 Feb, 2023
# ..      ...                  ...                    ...           ...
# 225  309106  Hollywood / English  English,French,German  09 Aug, 2019
# 226  260013   Bollywood / Indian                  Hindi  16 Apr, 2018
# 227  248674  Hollywood / English                English  30 Dec, 2017
# 228  141633  Hollywood / English                English  15 Aug, 2015
# 229   28921  Hollywood / English                English  13 Jun, 2013
#
#     release_date  run_time                                          storyline  \
# 0    Feb 17 2023       125  Scott\r\n Lang and Hope Van Dyne, along with H...
# 1    Jan 26 2023        95  Michelle\r\n and Allen are in a relationship. ...
# 2    Feb 15 2023       110  In late 1930's Bay City, a brooding, down on h...
# 3    Feb 15 2023       110  In late 1930's Bay City, a brooding, down on h...
# 4    Feb 15 2023       110  In late 1930's Bay City, a brooding, down on h...
# ..           ...       ...                                                ...
# 225  Jul 26 2019       106  A motherless and emotionally remote young man ...
# 226  Apr 06 2018       120  Sushant Dubey checks in at a beach resort of M...
# 227  Jan 01 1970  1h 29min  A woman in her third trimester of pregnancy is...
# 228  Aug 14 2015  1h 35min  In the near future, breathable air is nonexist...
# 229  Jun 12 2013        98  'Ed Harris' plays the captain of a Cold War So...
#
#                                  title    views  \
# 0    Ant-Man and the Wasp: Quantumania   39,399
# 1                           Maybe I Do    3,584
# 2                              Marlowe    3,044
# 3                              Marlowe    3,045
# 4                              Marlowe    3,046
# ..                                 ...      ...
# 225                       The Mountain    3,062
# 226                            Missing  202,010
# 227                             Inside   26,946
# 228                                Air   22,789
# 229                            Phantom   48,979
#
#                                                writer box_office_gross
# 0                           Jack Kirby, Jeff Loveness     $212,913,580
# 1                                      Michael Jacobs       $1,293,722
# 2    William Monahan, John Banville, Raymond Chandler       $4,350,243
# 3    William Monahan, John Banville, Raymond Chandler       $4,350,243
# 4    William Monahan, John Banville, Raymond Chandler       $4,350,243
# ..                                                ...              ...
# 225      Rick Alverson, Dustin Guy Defa, Colm O'Leary                -
# 226                                   Mukul Abhyankar      $32,502,025
# 227                                               NaN         $897,190
# 228               Christian Cantamessa, Chris Pasetto      $33,409,758
# 229                                     Todd Robinson                -
#
# [230 rows x 16 columns]
